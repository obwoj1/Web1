# %% [markdown]
# <a href="https://colab.research.google.com/github/obwoj1/Web-1/blob/main/Untitled21.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Dict to df

# %% [markdown]
# ##Dict

# %%
import pandas as pd
dict1 = {
    "names":["Lenny","Josh","Jay","Messi"],
    "ages":[23,24,25,26],
    "cities":["Baltimore","NewYork","Jersey","Baltimore"]
}
data = pd.DataFrame(dict1)
data
# Out:
#    names  ages     cities
# 0  Lenny    23  Baltimore
# 1   Josh    24    NewYork
# 2    Jay    25     Jersey
# 3  Messi    26  Baltimore
